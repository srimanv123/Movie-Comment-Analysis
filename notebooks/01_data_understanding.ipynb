# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\srima\OneDrive\Desktop\Movie_Comment_Analysis\data\Movie Comments Dataset.xlsx"
)

df.head()
# Out:
#       Video ID                                    Cleaned Comment  \
# 0  JZMT84XFbSk  If writer screenplay dialogues Is by Naveen di...
# 1  JZMT84XFbSk  this movie is excellent bro..niku anil ravipud...
# 2  JZMT84XFbSk  Its full family movie ra , stop seeing crime a...
# 3  JZMT84XFbSk  Exactly second half lo comedy scenes were too ...
# 4  JZMT84XFbSk                            Super movie.go watch it
#
#         Movie Rating Volgur Comment     Movie Category
# 0  Not able to Judge             No  Not Able to Judge
# 1          Excellent             No  Not Able to Judge
# 2            Neutral             No  Not Able to Judge
# 3          Very Good             No  Not Able to Judge
# 4          Very Good             No  Not Able to Judge

# %%
print(df.shape)
print(df.columns)
df.info()
# Out:
# (33994, 5)
# Index(['Video ID', 'Cleaned Comment', 'Movie Rating', 'Volgur Comment',
#        'Movie Category'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 33994 entries, 0 to 33993
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Video ID         29422 non-null  str
#  1   Cleaned Comment  29234 non-null  object
#  2   Movie Rating     29255 non-null  str
#  3   Volgur Comment   33994 non-null  str
#  4   Movie Category   33994 non-null  str
# dtypes: object(1), str(4)
# memory usage: 1.3+ MB

# %%
import nltk

# %%
import nltk

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# True

# %%
excel_file = pd.ExcelFile(
    r"C:\Users\srima\OneDrive\Desktop\Movie_Comment_Analysis\data\Movie Comments Dataset.xlsx"
)

print(excel_file.sheet_names)
# Out:
# ['Annotator_1', 'Annotator_2', 'Annotator_3']

# %%
df["Movie Rating"].value_counts(dropna=False)
df["Movie Category"].value_counts()
# Out:
# Movie Category
# Not Able to Judge    33993
# Action / Thriller        1
# Name: count, dtype: int64

# %%
print(df["Movie Rating"].value_counts(dropna=False))
# Out:
# Movie Rating
# Not able to Judge    24480
# NaN                   4739
# Very Good             1600
# Poor                  1176
# Excellent             1013
# Neutral                713
# Not Good               273
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#       Video ID                                    Cleaned Comment  \
# 0  JZMT84XFbSk  If writer screenplay dialogues Is by Naveen di...
# 1  JZMT84XFbSk  this movie is excellent bro..niku anil ravipud...
# 2  JZMT84XFbSk  Its full family movie ra , stop seeing crime a...
# 3  JZMT84XFbSk  Exactly second half lo comedy scenes were too ...
# 4  JZMT84XFbSk                            Super movie.go watch it
# 5  JZMT84XFbSk  Naku naaku golendira babu ..janalaki cinema au...
# 6  JZMT84XFbSk  First half avg. Emotional sequence in Second h...
# 7  JZMT84XFbSk  1. Rajasaab 2. Anaganaga oka Raju 3. MSG 4. NN...
# 8  JZMT84XFbSk  ఈ సంక్రాంతికి రాజా సాబ్ 🕺💃💃💃 మన శంకర వరప్రసాద్...
# 9  JZMT84XFbSk  Why are you reveling the plot or story what ev...
#
#         Movie Rating Volgur Comment     Movie Category
# 0  Not able to Judge             No  Not Able to Judge
# 1          Excellent             No  Not Able to Judge
# 2            Neutral             No  Not Able to Judge
# ...

# %%
df_clean = df.dropna(subset=["Cleaned Comment", "Movie Rating"])

# %%
df_clean = df_clean[
    df_clean["Movie Rating"] != "Not able to Judge"
]

# %%
print(df_clean.shape)
# Out:
# (4775, 5)

# %%
df_clean.to_csv(
    "../data/clean_movie_comments.csv",
    index=False
)

# %%
df_clean["Movie Rating"].value_counts().plot(
    kind="bar"
)
# Out:
# <Axes: xlabel='Movie Rating'>

# %%
df_clean["comment_length"] = (
    df_clean["Cleaned Comment"]
    .astype(str)
    .apply(len)
)

# %%
df_clean["comment_length"].describe()
# Out:
# count    4775.000000
# mean       67.779058
# std       136.680980
# min         1.000000
# 25%        18.000000
# 50%        34.000000
# 75%        71.000000
# max      3526.000000
# Name: comment_length, dtype: float64

# %%
df_clean.groupby(
    "Movie Rating"
)["comment_length"].mean()
# Out:
# Movie Rating
# Excellent     57.315893
# Neutral       95.497896
# Not Good     124.208791
# Poor          56.326531
# Very Good     60.840625
# Name: comment_length, dtype: float64

# %%
df_clean.shape
# Out:
# (4775, 6)

# %%
df_clean["Movie Rating"].value_counts()
# Out:
# Movie Rating
# Very Good    1600
# Poor         1176
# Excellent    1013
# Neutral       713
# Not Good      273
# Name: count, dtype: int64
